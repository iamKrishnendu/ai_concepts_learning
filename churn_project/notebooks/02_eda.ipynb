# %%
import pandas as pd

df = pd.read_excel("../data/churn.xlsx")

df["Churn Label"].value_counts()
df["Churn Label"].value_counts(normalize=True)
# Out:
# Churn Label
# No     0.73463
# Yes    0.26537
# Name: proportion, dtype: float64

# %% [markdown]
# Is churn blanaced or imbalanced?
#
# As The `Churn Label` shows values which are not equal, so, this is an Imbalanced churn

# %%
# Step:2 - Numerical Features vs Churn

import seaborn as sns
import matplotlib.pyplot as plt
#import pandas as pd

#df = pd.read_excel("../data/churn.xlsx")

sns.boxplot(x="Churn Label", y="Tenure Months", data=df)
plt.show()


sns.boxplot(x="Churn Label", y="Monthly Charges", data=df)
plt.show()
